# %%
import scipy.optimize
import random
from math import exp
from math import log
from collections import defaultdict
import gzip
import numpy as np

def readGz(f):
    for l in gzip.open(f):
        yield eval(l)

meta = defaultdict(dict)
for l in readGz('meta_Video_Games.json.gz'):
    if 'price' in l and 'salesRank' in l and l['salesRank']:
        meta[l['asin']] = l
        
data = []
for l in readGz('reviews_Video_Games.json.gz'):
    if l['asin'] in meta:
        data.append(l)
random.shuffle(data)

# %%
data[0]
# Out:
# {'asin': 'B000O5FTIY',
#  'helpful': [0, 1],
#  'overall': 5.0,
#  'reviewText': 'but this is another she cant stop playing....so i guess that has to mean something...she lets me play every once in a blue moon...',
#  'reviewTime': '02 21, 2010',
#  'reviewerID': 'A21WVMM3FA60QO',
#  'reviewerName': 'Heather Martin',
#  'summary': 'Gifted game again....',
#  'unixReviewTime': 1266710400}

# %%
meta['B000O5FTIY']
# Out:
# {'asin': 'B000O5FTIY',
#  'categories': [['Video Games', 'Kids & Family', 'Nintendo DS', 'Games'],
#   ['Video Games', 'Nintendo DS', 'Games']],
#  'description': 'Features include:&bull;Touchscreen Control: All of the 23 highly addictive games make exclusive use of the touchscreen and the stylus which is a natural fit for the Nintendo DS.&bull;Adhoc/Wi-Fi Wireless: Play solo or with friends via single card wireless play or utilize the Nintendo Wi-Fi connection to challenge friends worldwide via the Internet.&bull;Leaderboards &amp; Tournaments: Use the Nintendo DS Wi-Fi capability to connect to the Midway Tournament Server via the Internet for daily rankings, high scores, tournaments and more.',
#  'imUrl': 'http://ecx.images-amazon.com/images/I/517Xe6EUhlL._SX300_.jpg',
#  'price': 19.99,
#  'related': {'also_bought': ['B002JQ43BU',
#    'B0018RWMSW',
#    'B0045EI7IE',
#    'B0051PLQ8E',
#    'B002TDIENG',
#    'B000FW64ZS',
#    'B002DOC93C',
#    'B0050SVMCC',
#    'B003YHJJW6',
#    'B004J61WDU',
#    'B003S2L66Y',
#    'B0045YKOXK',
#    'B005FYK2QI',
#    'B0036KRP72',
#    'B001C58T50',
#    'B002F9005O',
#    'B002FUI4M4',
#    'B002KJCVYW',
#    'B000EGELQ4',
#    'B0019C6KC0',
#    'B002EE5RD0',
#    'B003VJJJNG',
#    'B001C58T5A',
#    'B000WCIHCE',
#    'B000TTZMCS',
#    'B001LX4BN2',
#    'B00524S8EE',
#    'B007VX0ALI',
#    'B00B5U3588',
#    'B007W8S2OE',
#    'B00498T4F6',
#    'B003DZX3U8',
#    'B000U5TVGY',
#    'B000SH3XGS',
#    'B008YAGTDU',
#    'B002MBMI46',
#    'B004ML63A4',
#    'B000E9TBRK',
#    'B000NW91B4',
#    'B000EGELP0',
#    'B002Q7NBUQ',
#    'B000QUYHIK',
#    'B005XO9FWM',
#    'B0013LTP6U',
#    'B003S2OO04',
#    'B002B3LG98',
#    'B004XIQO3W',
#    'B003OPYSLK',
#    'B008SBODGU',
#    'B00076OMOW',
#    'B000BIZR72',
#    'B002I0GU2M',
#    'B008YVPNPO',
#    'B002EWD02W',
#    'B0069EB9BK',
#    'B001C3N0QA',
#    'B004RLL4XK',
#    'B000UZRWKQ',
#    'B005DEM4UC',
#    'B0042A147M',
#    'B003VJRNYS',
#    'B001BR5QLO',
#    'B0007P0U3U',
#    'B000Q6ZLGG',
#    'B002I0EPBA',
#    '3828770193',
#    'B005J3J5E0',
#    'B000V6I7TE',
#    'B003V63V2O',
#    'B0013LTP6K',
#    'B000ME25P2',
#    'B000HKKQ3Y',
#    'B00189MNQG',
#    'B002B1TDV8',
#    'B000P2XJ92',
#    'B003P9BIAY',
#    'B000HKGMKK',
#    'B000Q6ZLH0',
#    'B000A3ON5A',
#    'B000X25GWW',
#    'B0033BJSDI',
#    'B001WCN250',
#    'B000MTK2KM',
#    'B001EQPDNS',
#    'B001EQPDO2',
#    'B003LDKLNO',
#    'B007PX6MFM',
#    'B004398WMW',
#    'B004ML6386',
#    'B0050GGKPS',
#    'B000FIH72G',
#    'B000SQ5LPK',
#    'B003KMJ9N4',
#    'B001V135P4',
#    'B001E22VT6',
#    'B000SH3XAY',
#    'B004863A54',
#    'B0013M2SJ0',
#    'B0006G4KR2'],
#   'bought_together': ['B002JQ43BU', 'B0018RWMSW'],
#   'buy_after_viewing': ['B0050SVMCC',
#    'B002JQ43BU',
#    'B0045EI7IE',
#    'B0018RWMSW']},
#  'salesRank': {'Video Games': 5365}}

# %%
s = set()
for l in meta:
    s |= set(meta[l]['categories'][0])
len(s),s

# %%
length = len(data)
platforms = ['VGA', 'PC', 'Linux', 'Mac', 'Nintendo', 'PlayStation', 'Sony PSP', 'Wii', 'Xbox']
def feature(datum):
    l = meta[datum['asin']]
    feat = [1] + [any([1 for c in l['categories'][0] if c.startswith(p)]) for p in platforms]
    feat += [l['price']/10.0, l['salesRank'].values()[0]]
    return feat

X = [feature(d) for d in data]
y = [d['overall'] for d in data]
X_train = X[:length*6/10]
y_train = y[:length*6/10]
X_test = X[length*6/10:length*8/10]
y_test = y[length*6/10:length*8/10]

theta,residuals,rank,s = np.linalg.lstsq(X, y)

MSE = [(np.dot(theta,X_test[i])-y_test[i])**2 for i in xrange(len(X_test))]
MSE = sum(MSE)/len(MSE)
print 'MSE',MSE

MAE = [abs(np.dot(theta,X_test[i])-y_test[i]) for i in xrange(len(X_test))]
MAE = sum(MAE)/len(MAE)
print 'MAE', MAE
# Out:
# MSE 1.86391769229
# MAE 1.10660946433

# %%
theta
# Out:
# array([  4.03230190e+00,  -1.00008011e+00,  -4.21752024e-01,
#         -2.35457948e-02,  -5.13116241e-01,   1.77030849e-01,
#          3.03055887e-02,   2.74934858e-02,  -3.73751565e-02,
#         -6.06404019e-02,   9.57353770e-03,  -4.44710549e-06])

# %%
meta
# Out:
# defaultdict(dict,
#             {'B0002CHJ3W': {'asin': 'B0002CHJ3W',
#               'categories': [['Video Games', 'More Systems', 'Xbox']],
#               'description': "Prince of Persia Warrior Within is a sword-slashing sequel to the hit game, Prince Of Persia: Sands Of Time. This time, our Prince is hunted by Dahaka, an immortal incarnation of Fate. The spirit seeks retirbution against the Prince, but he is wiser and deadlier than he was. To avoid his preordained death, he'll travel to the infernal core of mankind's worst fears.",
#               'imUrl': 'http://ecx.images-amazon.com/images/I/41YZM936G4L.jpg',
#               'price': 23.88,
#               'related': {'also_bought': ['B0009Z3IV4',
#                 'B00009ZVHU',
#                 'B0030GBUCS',
#                 'B001ASJISG',
#                 'B001ELWMHI',
#                 'B0001UEHP8',
#                 'B00008H2IU',
#                 'B000067DPM',
#                 'B000F2JUOK',
#                 'B0002SQ0BS',
#                 'B000087L4G',
#                 'B0008JILX6',
#                 'B00012TIW8',
#                 'B0008GJRQ4',
#                 'B00006JZQZ',
#                 'B00008XKZM',
#                 'B0002B90SA',
#                 'B000SQ5LQ4',
#                 'B0002CHIZ6',
#                 'B000641ZCM',
#                 'B00269DXCK',
#                 'B0000A082T',
#                 'B00020BV1A',
#                 'B0007KTBC6',
#                 'B0016CQ0Q4',
#                 'B0009351RK',
#                 'B00005NZ1G',
#                 'B0001KUE7S',
#                 'B000095ZH0',
#                 'B004AGYHUE',
#                 'B000ZK9QCS',
#                 'B00006F2ZQ',
#                 'B00006JN5J',
#                 'B000B6MLZK',
#                 'B00005RKO7',
#                 'B00008KTNW',
#                 'B002I0JGDM',
#                 'B00DBCAT3W',
#                 'B000784XGM',
#                 'B0002CTTJO'],
#                'bought_together': ['B0009Z3IV4', 'B00009ZVHU'],
#                'buy_after_viewing': ['B00009ZVHU',
#                 'B0030GBUCS',
#                 'B001ASJISG',
#                 'B004J6I0YO']},
#               'salesRank': {'Video Games': 22579}},
#              'B008BT80SQ': {'asin': 'B008BT80SQ',
#               'categories': [['Video Games', 'PC', 'Games']],
#               'description': 'F1 2012 is designed to be the most accessible and immersive Formula One game for fans and racing game enthusiasts of all abilities. Players will feel the passion, speed and glory of the world&#x2019;s most glamorous sport with a host of new features, wide-ranging technical and gameplay advancements and extensive competitive and co-operative multiplayer components. Through the inclusion of the Young Driver Test, a range of tutorials will introduce new players to Formula One racing and explain how to handle motorsport&#x2019;s most exciting and responsive cars.',
#               'imUrl': 'http://ecx.images-amazon.com/images/I/51cLdSO7kvL._SY300_.jpg',
#               'price': 49.99,
#               'related': {'also_bought': ['0700099867',
#                 'B006IR6NH8',
#                 'B0018XWLKA',
#                 'B00488PZ0U',
#                 'B00ED02812',
#                 'B0016O5G62',
#                 'B000ODVKUC',
#                 'B001NT9TK4',
#                 'B000VOSQ0Q',
#                 'B00140R0XK',
#                 'B000C97156',
#                 'B007MNWVJG',
#                 'B002AQNT96',
#                 'B0050SWS8O',
#                 'B005S2TW4K',
#                 'B00CZ8SSKY',
#                 'B00092CJLW',
#                 'B001TOMR84',
#                 'B004VF06AY',
#                 'B002I0HFNU',
#                 'B00CTKHZI4',
#                 '8176503290',
#                 'B005QIO40S',
#                 'B002I0HFBC',
#                 'B001EAORVS',
#                 'B003IHVN3A',
#                 'B002I9PQ00',
#                 'B002BS47YE',
#                 '0700026711',
#                 'B000062VQK',
#                 'B002ACEAR0',
#                 'B005PPOBQE',
#                 'B003CF4Y7A',
#                 'B00GNZM0B8',
#                 'B001DPZE84',
#                 'B003R79HFW',
#                 'B000VRCNLG',
#                 'B008AHMEFO',
#                 'B00EZ16S5G',
#                 'B001Q96ZNU',
#                 'B0000C0Z23',
#                 '0754827615',
#                 'B000U5RRX8',
#                 'B0057F5LWA',
#                 'B001BPQ1VA',
#                 'B002S1LP5S',
#                 'B0050SZ0SY',
#                 'B004AYMCRG',
#                 'B003UEREBQ',
#                 'B007MMINWQ',
#                 '085733350X',
#                 'B004J6KRD6',
#                 'B0039SM09Y',
#                 'B0016N4A7E',
#                 'B000COCAJI',
#                 'B000U1OOH4',
#                 'B000OPPR72',
#                 'B003ZY3H4E',
#                 'B005UXOHP6',
#                 'B000H4EO6K',
#                 'B00BJ60LEY',
#                 'B009CYMNDM',
#                 'B00CRL9TU2',
#                 'B000VM9DMI',
#                 'B000651WII',
#                 'B0015HYPOO',
#                 'B005O6Z028',
#                 'B001VJ4DHK',
#                 'B002I0IHIM',
#                 'B007XVTR12',
#                 'B004QRKWLA',
#                 'B000AOTLP6',
#                 '0857330993',
#                 'B0007UQ0OS',
#                 'B00BEIYP8A',
#                 'B0056WJA7Q',
#                 'B000VRH6Y0',
#                 'B007TMFD7M',
#                 'B003VAHYQY',
#                 'B000U90L32',
#                 'B001QRWE14',
#                 'B001ED2VAO',
#                 'B002I0KOSI',
#                 'B00BPANZ60',
#                 'B00EDJLXHI',
#                 'B0050SWTS8',
#                 'B004QRKWKQ',
#                 'B001UVV8QS',
#                 'B0050SZ0JI',
#                 'B0029M6VKA',
#                 'B00DWAZ8PM',
#                 'B001988XHY',
#                 'B0013RC1W4',
#                 'B005KQ99O2'],
#                'bought_together': ['0700099867', 'B001NT9TK4'],
#                'buy_after_viewing': ['B00ED02812',
#                 'B001NT9TK4',
#                 '0700099867',
#                 'B00488PZ0U']},
#               'salesRank': {'Video Games': 13580}},
#              'B000GG6SMC': {'asin': 'B000GG6SMC',
#               'categories': [['Video Games', 'PC', 'Games']],
#               'description': "Choose&nbsp; an adorable puppy from 5 differentbreedsProduct InformationPut an adorable puppy in your PC!&nbsp; This amazing virtual pet needs foodwater grooming and discipline just like a real animal.&nbsp; But most of allit needs your love.&nbsp; Teach your clever puppy all kinds of tricks.&nbsp;You and your kitten can decorate your house together.&nbsp; You can train andbeautify your panion to win fame and fortune in the talent shows.&nbsp; Oryou can watch it soak up your attention.&nbsp; Either way you have a wonderfulnew friend who's always ready to play!Includes Beagle:&nbsp; These hunting dogs are bundles of energy.&nbsp; Beagles are very loving but also very independent so it takes patience to train them.&nbsp; Short hair makes them easy to groom. Careful! These little pranksters will scratch up anything they can. Border Collie:&nbsp; These intelligent dogs are a pleasure to train.&nbsp; Border collies are loving and obedient panions.&nbsp; However their long hair requires more attention than other breeds'. German Shepherd:&nbsp; Shepherds are loyal pets.&nbsp; Their capacity for love is nearly boundless.&nbsp; they are also very adept learners.&nbsp; Their long fur is tricky to manage though and they bark more than other breeds. Labrador Retriever:&nbsp; These little puppies love to play.&nbsp; They are bright and quick friendly and loving.&nbsp; Labs are fast learners but may have trouble paying attention.&nbsp; They also need more water than other breeds as they tend to slobber. Pug:&nbsp; These puppies are little jokers.&nbsp; They love to play and they're very loving.&nbsp; Training a pug is tricky but they love the attention so you won't mind.&nbsp; Show them all the love you've got and they'll love you right back.&nbsp; Short hair makes grooming",
#               'imUrl': 'http://ecx.images-amazon.com/images/I/51QCn0oBiDL._SY300_.jpg',
#               'price': 19.99,
#               'related': {'also_bought': ['B000GG8JDI',
#                 'B000SL4AL6',
#                 'B000U850Z2',
#                 'B004077RY6',
#                 'B000FX4X3M'],
#                'bought_together': ['B000GG8JDI', 'B000SL4AL6'],
#                'buy_after_viewing': ['B0006B5LQ6',
#                 'B000SL4AL6',
#                 'B000U850Z2',
#                 'B00006JEL3']},
#               'salesRank': {'Video Games': 41180}},
#              'B0018OK9YO': {'asin': 'B0018OK9YO',
#               'categories': [['Video Games',
#                 'More Systems',
#                 'Sega Genesis',
#                 'Hardware',
#                 'Accessories']],
#               'description': '16 Bit Joystick with flashing lights to show you the speed of the adjustable turbo.',
#               'imUrl': 'http://ecx.images-amazon.com/images/I/213hFTg1P4L.jpg',
#               'price': 5.23,
#               'related': {'also_viewed': ['B002HP18IO',
#                 'B0036C0OFA',
#                 'B00EAM862S',
#                 'B0007MZWQS',
#                 'B000FUIS40',
#                 'B0057WDBHA',
#                 'B00ALI2OYG',
#                 'B00002ST8H',
#                 'B000035XR9',
#                 'B00HM3QAWK',
#                 'B000A7FEOU',
#                 'B0009O8UDG',
#                 'B002FY0CM0',
#                 'B000035XQN',
#                 'B00002SVOG',
#                 'B0042PXJT8',
#                 'B00BXPIO1S',
#                 'B00002SVRC',
#                 'B00E6LHQVU',
#                 'B001M25AY6',
#                 'B001DJNF4A',
#                 'B00005CDR8',
#                 'B00004SVXA',
#                 'B001CYBXMC',
#                 'B0094H8H7I',
#                 'B00004SVOG',
#                 'B000035XKJ',
#                 'B0091GS8R6',
#                 'B0080RAT42',
#                 'B0057WDE8Q',
#                 'B003O3EFY2',
#                 'B00063QDNY',
#                 'B000L8L1E0',
#                 'B001G33V8S',
#                 'B00002ST7F',
#                 'B00002SVFZ',
#                 'B00002ST82',
#                 'B003Y5AHPG',
#                 'B00012O7UQ',
#                 'B002GCFI2K',
#                 'B00005O4G5',
#                 'B00005C7QT',
#                 'B0015PHMFU',
#                 'B00002SUD0',
#                 'B000035XLL',
#                 'B000035XLT'],
#                'buy_after_viewing': ['B002HP18IO',
#                 'B002FY0CM0',
#                 'B0036C0OFA',
#                 'B0089ZLXHW']},
#               'salesRank': {'Video Games': 41940}},
#              'B00CWPRERS': {'asin': 'B00CWPRERS',
#               'categories': [['Video Games',
#                 'PlayStation 3',
#                 'Accessories',
#                 'Skins']],
#               'description': 'skin for system and 2 controllers',
#               'imUrl': 'http://ecx.images-amazon.com/images/I/51T5Q771ahL._SY300_.jpg',
#               'price': 16.99,
#               'related': {'also_viewed': ['B00F9KMCPC',
#                 'B00B6BLQ2S',
#                 'B00J1F22EW',
#                 'B00GS12670',
#                 'B00FPU48I0',
#                 'B00BUG8G2W',
#                 'B00JE6ZTUW',
#                 'B008DBJPLS',
#                 'B00FSFLXDA',
#                 'B0041S1MVI',
#                 'B00J1F4DD0',
#                 'B002PNMMYC',
#                 'B001NIOP7M',
#                 'B00I3WSBVC',
#                 'B001UNZNLW',
#                 'B00FPU3VRY',
#                 'B002X2P5AS',
#                 'B008DBO4UK',
#                 'B00GS0GKLO',
#                 'B00GMIK5HW',
#                 'B007SO6USW',
#                 'B001UO3DRM',
#                 'B005LN5UOC',
#                 'B00JE70CQC',
#                 'B00701POBM',
#                 'B00447WC88',
#                 'B008WXKMFK',
#                 'B00JE707FS',
#                 'B00J7K5WLG',
#                 'B00CWPT7NC',
#                 'B005JB45OC',
#                 'B002Q011SW',
#                 'B005M8GSAQ',
#                 'B0054M04QE',
#                 'B007FVVXXA',
#                 'B0053OLY9O',
#                 'B00IA51FFG',
#                 'B00I3WUGSS',
#                 'B00AEX81SG',
#                 'B00F9KN1JS',
#                 'B00BURTGLG',
#                 'B00I3WSCXO',
#                 'B00HK74G2E',
#                 'B002GJRQSC',
#                 'B00BWBTJ4Y',
#                 'B00E369SDM'],
#                'buy_after_viewing': ['B00F9KMCPC']},
#               'salesRank': {'Video Games': 46151}},
#              'B0002CHJ3C': {'asin': 'B0002CHJ3C',
#               'categories': [['Video Games',
#                 'More Systems',
#                 'GameCube',
#                 'Games']],
#               'description': "Prince of Persia Warrior Within is a sword-slashing sequel to the hit game, Prince Of Persia: Sands Of Time. This time, our Prince is hunted by Dahaka, an immortal incarnation of Fate. The spirit seeks retribution against the Prince, but he is wiser and deadlir than he was. To avoid his preordained death, he'll travel to the infernal core of mankind's worst fears.",
#               'imUrl': 'http://ecx.images-amazon.com/images/I/515GW510ZTL._SY300_.jpg',
#               'price': 103.48,
#               'related': {'also_bought': ['B0009Z3IVY',
#                 'B00009ZVI2',
#                 'B0002A6CQ4',
#                 'B00006IJJK',
#                 'B0002CHIWO',
#                 'B00006LU9B',
#                 'B00006LELI',
#                 'B0009Z3I0K',
#                 'B00006IJJI',
#                 'B00006599U',
#                 'B00008KTW2',
#                 'B00008H2IS',
#                 'B0009UBR3A',
#                 'B0002CHJ5K',
#                 'B000ARPXU0',
#                 'B00009KO3S',
#                 'B0009PCQD0',
#                 'B00009WAUH',
#                 'B000083JTS',
#                 'B00009X3V2',
#                 'B00005Q8M4',
#                 'B00009YEKA',
#                 'B0002ILS1U',
#                 'B00005Q8LG',
#                 'B000088KH2',
#                 'B00005QDPZ',
#                 'B000E5N4SG',
#                 'B000067DPN',
#                 'B00012D0SG',
#                 'B00009PS24',
#                 'B000067K2D',
#                 'B000070IWB',
#                 'B00005U8TI',
#                 'B0000A1OG4',
#                 'B0000E5U6I',
#                 'B0001B167O',
#                 'B00006FDLO',
#                 'B0002XL3BA',
#                 '9861019731',
#                 'B00006599P',
#                 'B000CC58VM',
#                 'B00006N5SB',
#                 'B000066JRN',
#                 'B00007E1OC',
#                 'B0006ZJP8C',
#                 'B004CHLNWQ',
#                 'B00000INR2',
#                 'B0019SY1D4',
#                 'B00009K04M',
#                 'B00007E1OH',
#                 'B00006YXLE',
#                 'B00006IJJC',
#                 'B0000ARQMV',
#                 'B0002TVX82',
#                 'B000Z9A95M',
#                 'B0001I9YIK',
#                 'B0009XEC0M',
#                 'B000FQ9QVI',
#                 'B00005QEFF',
#                 'B000095ZHA',
#                 'B000G6SPHI',
#                 'B000A15K0Y',
#                 'B0002ILS24',
#                 'B00009XS6R',
#                 'B0030GBU8W',
#                 'B000084318',
#                 'B00008DHLL',
#                 'B00006AVB1',
#                 'B002BSC4ZS',
#                 'B00006JZDV',
#                 'B000GOZIDO',
#                 'B00008KTWG',
#                 'B00008KTWH',
#                 'B0002XCCU6',
#                 'B00005ULXN',
#                 'B0000A0834',
#                 'B000P297ES',
#                 'B0002I9RQI',
#                 'B00008G8IA',
#                 'B001AI7CF2',
#                 'B00006LEMY',
#                 'B0008GJRT6',
#                 'B00006IJJL',
#                 'B001P5HM64',
#                 'B0009XSMNA',
#                 'B0030GBU28',
#                 'B00006LELB',
#                 'B00005QEFD',
#                 'B000AQA9UA',
#                 'B00006FWU6',
#                 'B00005Q8LR',
#                 'B000090W86',
#                 'B0001OK7V2',
#                 'B0002WYUB6',
#                 'B0000A09EI',
#                 'B00095KU5G',
#                 'B000GACEHQ'],
#                'bought_together': ['B00009ZVI2'],
#                'buy_after_viewing': ['B00009ZVI2',
#                 'B00006IJJK',
#                 'B00009PS22',
#                 'B0002A6CQ4']},
#               'salesRank': {'Video Games': 25551}},
#              '0671317091': {'asin': '0671317091',
#               'categories': [['Video Games', 'PC', 'Games']],
#               'description': "At the heart of our Galaxy, an advanced civilization of which we know nothing has built the biggest, most beautiful starship ever, the Starship Titanic. Majestic and luxurious, its interior resembles a mixture of the Ritz, the Chrysler building, Tutankhamen's tomb and Venice. Starship Titanic is a technological marvel. And it cannot possibly go wrong. In theory. Seconds into its maiden voyage it crashes into hyperspace, vanishes... ... and collides with your house. Bewildered, you find your way aboard, and just as you are gazing at its awe-inspiring interior, the ship takes off again and heads deep into space. You are stranded. But you are not along. The ship is inhabited by a crew of malfunctioning robots and a semi-deranged parrot. You discover that you can communicate with them, a feat that is made possible by SpookiTalk, the games proprietary interactive language engine. You can chat with any of the robot characters, like Fentible the distinguished Doorbot, Nobby the hypochondriac Liftbot, or Fortillian Bantoburn O' Perfluous the outrageously convivial Barbot. Talk to them. Interrogate them. Give them orders. They will listen to you, answer you and, if they happen to feel like it, obey you. Sometimes.",
#               'imUrl': 'http://ecx.images-amazon.com/images/I/51iFNnzZImL._SY300_.jpg',
#               'price': 12.5,
#               'related': {'also_viewed': ['0345368436',
#                 'B000069CCI',
#                 'B00002SAO1',
#                 'B00001SVEC'],
#                'buy_after_viewing': ['0345368436',
#                 'B000069CCI',
#                 '0307236013',
#                 '0671746723']},
#               'salesRank': {'Video Games': 52684}},
#              'B003V4AK66': {'asin': 'B003V4AK66',
#               'categories': [['Video Games',
#                 'Nintendo DS',
#                 'Accessories',
#                 'Cases & Protectors']],
#               'description': 'Protect your Nintendo DSi system with this sleek case featuring your favorite Nintendo Characters in fun and vibrant colors. Available in Green/Yoshi, Pink/Peach, and Red/Mario. Officially licensed Nintendo product developed by POWER A. Nintendo DSi game system sold separately.',
#               'imUrl': 'http://ecx.images-amazon.com/images/I/41J4Ivd9TdL._SY300_.jpg',
#               'price': 25.89,
#               'related': {'also_viewed': ['B003V4AK70',
#                 'B007FMSGG6',
#                 'B003981JOG',
#                 'B003V4AK7A',
#                 'B00EZLBCHK',
#                 'B0035I4LWW']},
#               'salesRank': {'Video Games': 42688}},
#              'B0002CHJ3M': {'asin': 'B0002CHJ3M',
#               'categories': [['Video Games',
#                 'More Systems',
#                 'PlayStation 2',
#                 'Games']],
#               'description': 'The Old Man said to the Prince, "Your fate has been written. You will die."Enter the dark underworld ofPrince of Persia 2, the sword-slashing sequel to the critically acclaimedPrince of Persia: The Sands of Time.Hunted by Dahaka, an immortal incarnation of Fate seeking divine retribution, the Prince embarks upon a path of both carnage and mystery to defy his preordained death. His journey leads to the infernal core of a cursed island stronghold harboring mankind\'s greatest fears.Only through grim resolve, bitter defiance and the mastery of deadly new combat arts can the Prince rise to a new level of warriorship - and emerge from this ultimate trial with his life.Key FeaturesThe Game of the Year returns: Prince of Persia 2 is the highly anticipated sequel to the universally acclaimedPrince of Persia: The Sands of Time, the undisputed Console Game of the Year for 2003.A warrior reborn: The Prince has matured immeasurably since his courageous fight inPrince of Persia: The Sands of Time. He returns here with deadlier skills, a darker heart, and a craving for battle.Free-form fighting system: An intricate new combat system lets you wage battles with no boundaries. Manipulate the environment and the enemies themselves to develop your own unique fighting style. Plus, an all-new projectile attack system allows for a variety of ranged combat tactics.A violent underworld revealed: Explore and conquer a cursed island underworld, breeding ground for the most brutal, unrelenting monsters to torment mankind.Control the ravages of time: Ravage enemies with the devastating new combative powers of the Sands of Time, opening up astounding variations in fighting game play.Fight harder, play longer: Hours upon hours of action await in your fight for survival, including various bonus incentives for those who finish the game.',
#               'imUrl': 'http://ecx.images-amazon.com/images/I/51VBKV259ZL._SY300_.jpg',
#               'price': 47.03,
#               'related': {'also_bought': ['B000A0EFJM',
#                 'B00009ZVHY',
#                 'B0002XL3BA',
#                 'B000G6SPHI',
#                 'B00005NCCR',
#                 'B0009I6S0O',
#                 'B00020LZAW',
#                 'B000B69E9G',
#                 'B000E49SGE',
#                 'B000099T1Y',
#                 'B00009VE6D',
#                 'B00020LZAM',
#                 'B0000B0MNH',
#                 'B0002IQCSY',
#                 'B0000C4M22',
#                 'B00020LZBG',
#                 'B00007E1OA',
#                 'B000UH6GEM',
#                 'B0009351R0',
#                 'B0009VQANG',
#                 'B0030GBUCS',
#                 'B00005R5PO',
#                 'B000935256',
#                 'B000099T2E',
#                 'B00005TNI6',
#                 'B0002B90OE',
#                 'B00008H2IW',
#                 'B000GPVUQ2',
#                 'B00006GSNX',
#                 'B00005U8TQ',
#                 'B000088KH1',
#                 'B000EMJA3M',
#                 'B000083JTR',
#                 'B0000A0MDV',
#                 'B0000690ZE',
#                 'B00019AZBO',
#                 'B0009Z3HYW',
#                 'B0001VGFK2',
#                 'B00005OLX1',
#                 'B0009SQF0C',
#                 'B0000696CZ',
#                 'B0000A09EM',
#                 'B0009RG8DW',
#                 'B0009VRSIC',
#                 'B0009A4EVM',
#                 'B00006AN1F',
#                 'B00004TNB0',
#                 'B00002SVWG',
#                 'B0000664JF',
#                 'B000069BD9',
#                 'B00004YRQA',
#                 'B0002Y2XXQ',
#                 'B0002EJ8FC',
#                 'B001LKM0EW',
#                 'B0009I6S0Y',
#                 'B00004U5VF',
#                 'B0009EHQVI',
#                 'B0033T1UWW',
#                 'B0000A8VBZ',
#                 'B000FDDN2E',
#                 'B0009Z3K9O',
#                 'B00005ME6N',
#                 'B0002CHJ8C',
#                 'B00005BIG7',
#                 'B0030GBU8W',
#                 'B0007PLKZM',
#                 'B000NJH6PU',
#                 'B0015Z1I4G',
#                 'B001G3B0HC',
#                 'B0001AVSGY',
#                 'B00004YRQ9',
#                 'B000066TS5',
#                 'B00004YUWA',
#                 'B000V7889C',
#                 'B000N0WBL8',
#                 'B00008URUA',
#                 'B000F5IH2I',
#                 'B0009F3E1I',
#                 'B00005O0I2',
#                 'B001MW91IW',
#                 'B0009VRSJ6',
#                 'B000930DLO',
#                 'B001ASJIS6',
#                 'B000EHQDA0',
#                 '9629971372',
#                 'B0001I9YHG',
#                 'B00000K1VA',
#                 'B0002CNUN0',
#                 'B0009O7HVW',
#                 'B000HQBZOM',
#                 'B000KCX9M4',
#                 'B0001I9YGC',
#                 'B00006GSNZ',
#                 'B00005CF9L',
#                 'B002I0H0SA',
#                 'B00004U5VK',
#                 'B00009YEK1',
#                 'B000G77X34',
#                 'B0009XBWY6',
#                 'B0009350BW'],
#                'bought_together': ['B000A0EFJM', 'B00009ZVHY'],
#                'buy_after_viewing': ['B00009ZVHY',
#                 'B000A0EFJM',
#                 'B0002XL3BA',
#                 'B0001ADAME']},
#               'salesRank': {'Video Games': 15645}},
#              'B00004T0QS': {'asin': 'B00004T0QS',
#               'categories': [['Video Games', 'Kids & Family'],
#                ['Video Games', 'More Systems', 'Linux Games'],
#                ['Video Games', 'PC', 'Games']],
#               'description': "The citizens of the megalopolis are unhappy with Hizzoner. Crime is out of control. Traffic is clogging the city's main arteries. Pollution is soaring. And to top it all, the pro sports team is threatening to move to the next city unless they get that new stadium...but you can step in as the mayor and commissioner of this fine city and save the day with your planning and building skills!The famousSimCityseries from Maxis is now on its way to Linux at last! Now you can get down and dirty with zoning, energy consumption, crime control, and taxation, all in the hopes of keeping those finicky Sims happy in your metropolis -- or suffer their wrath at the ballot box.SimCity 3000 Unlimitedis the latest installment in this classic series, and now you can play it on Linux and you can play it in 9 different languages (English, French, German, Dutch, Italian, Polish, Portuguese, Spanish and Swedish)!",
#               'imUrl': 'http://ecx.images-amazon.com/images/I/61S533MDJXL._SY300_.jpg',
#               'price': 29.95,
#               'related': {'also_viewed': ['B00004T1M7',
#                 'B00000G16I',
#                 'B0000E2HFT',
#                 'B00006F7S8'],
#                'buy_after_viewing': ['B00004T1M7', 'B0000C0YW2']},
#               'salesRank': {'Video Games': 63758}},
#              'B00004T0QP': {'asin': 'B00004T0QP',
#               'categories': [['Video Games', 'PC', 'Games']],
#               'description': 'Flying Heroesis a real-time first-person aerial combat game, merging technology and classic high fantasy in an airborne gladiatorial fight for survival. Fight elite airborne warriors high above the fantastic lands of Hesperia, riding atop the giant Deborean birds or piloting the technological marvels of the Hammercraft and more, in the ceremonial battles for national supremacy.',
#               'imUrl': 'http://ecx.images-amazon.com/images/I/51CYRMGYBAL._SY300_.jpg',
#               'price': 8.0,
#               'salesRank': {'Video Games': 54343}},
#              'B001XCWTPS': {'asin': 'B001XCWTPS',
#               'categories': [['Video Games', 'Digital Games', 'Casual Games'],
#                ['Video Games', 'Digital Games', 'PC Game Downloads'],
#                ['Video Games', 'PC', 'Games']],
#               'description': 'When a giant menace threatens the village, the young faeries Delfbert, Wilf and Angelica set out on a journey to save their home! Join them on their quest through 100 puzzling levels of stunning graphics and magical music that will fill you with wonder.  Featuring an exciting new type of puzzle game play and a humorous, light hearted storyline sure to make you smile, A Fairy Tale is an unforgettable journey of enchantment!',
#               'imUrl': 'http://ecx.images-amazon.com/images/I/41a9urVSJPL.jpg',
#               'price': 9.99,
#               'related': {'also_viewed': ['B001KC03Q8',
#                 'B001KC00PM',
#                 'B002BNKQHQ',
#                 'B0030EFV9S',
#                 'B001KC00HA',
#                 'B0040GJ6MI',
#                 'B001KC01RO',
#                 'B0042JSZEI',
#                 'B001KC00BQ',
#                 'B0046W6U3O',
#                 'B001KC009S',
#                 'B001KBZZYO',
#                 'B001KC006Q',
#                 'B001K7HV2M',
#                 'B0040GJ6NM',
#                 'B004MMEGHU',
#                 'B008A07U0U'],
#                'buy_after_viewing': ['B001KC03Q8']},
#               'salesRank': {'Video Games': 43327}},
#              'B00FLY3QSS': {'asin': 'B00FLY3QSS',
#               'categories': [['Video Games', 'Xbox 360', 'Games']],
#               'imUrl': 'http://ecx.images-amazon.com/images/I/51bQMLxPUSL._SY300_.jpg',
#               'price': 29.99,
#               'related': {'also_viewed': ['B001PB9J14',
#                 'B00CFLH46K',
#                 'B00H2QMAQ2',
#                 'B00BI7ZP2M',
#                 'B0050JN7VU',
#                 'B00FLY8A84',
#                 'B003O6G6RI'],
#                'buy_after_viewing': ['B001PB9J14']},
#               'salesRank': {'Video Games': 23300}},
#              'B00004T0QU': {'asin': 'B00004T0QU',
#               'categories': [['Video Games', 'PC', 'Games']],
#               'description': 'The game takes place in the year 2161, after Earth has colonized Primus IV to exploit the rich deposits of a new element, called SL18. After some skirmishing with scattered indigenous life forms, the colonists take hold of Primus IV and begin mining SL18. Fast-forward 40 years--the colonists have been consistently used and abused by Earth, as SL18 turns out to be a valuable military-grade material. Using their newfound wealth from controlling the only known supply of SL18 in space, the colonists of Primus IV declare their independence from Earth, hiring an elite mercenary force, the WarMonkeys, for the assault they know will come from Earth. As expected, Earth retaliates by sending a contingent of its veteran Imperial Order division to quell the rebellion. And, after 40 years of breeding, the indigenous Mantai emerge from their subterranean lairs to erase humanity from the face of their home world.',
#               'imUrl': 'http://ecx.images-amazon.com/images/I/518TA191DNL._SY300_.jpg',
#               'price': 6.06,
#               'salesRank': {'Video Games': 82446}},
#              'B000035XW4': {'asin': 'B000035XW4',
#               'categories': [['Video Games',
#                 'More Systems',
#                 'PlayStation',
#                 'Hardware',
#                 'Accessories'],
#                ['Video Games',
#                 'More Systems',
#                 'Sega Saturn',
#                 'Hardware',
#                 'Accessories']],
#               'description': 'nyko cobra light gun and works great,blue in color',
#               'imUrl': 'http://ecx.images-amazon.com/images/I/31aEPxaBdGL.jpg',
#               'price': 24.99,
#               'related': {'also_viewed': ['B000021XP4',
#                 'B00004SVZH',
#                 'B00003ZL4Y',
#                 'B000EO70XC'],
#                'buy_after_viewing': ['B00004SVZH',
#                 'B000021XP4',
#                 'B004H60Y0E']},
#               'salesRank': {'Video Games': 39060}},
#              'B0009VYCL8': {'asin': 'B0009VYCL8',
#               'categories': [['Video Games', 'PC', 'Games']],
#               'imUrl': 'http://ecx.images-amazon.com/images/I/516PJ7JKDML._SY300_.jpg',
#               'price': 13.25,
#               'related': {'also_viewed': ['B000056V6H',
#                 'B00002CF8V',
#                 'B00004U8KR',
#                 '0743411897',
#                 'B00004U8KN',
#                 'B00004U8KQ'],
#                'buy_after_viewing': ['B000056V6H', 'B00002CF8V']},
#               'salesRank': {'Video Games': 61794}},
#              'B00189MNPW': {'asin': 'B00189MNPW',
#               'categories': [['Video Games', 'Kids & Family', 'Wii', 'Games'],
#                ['Video Games', 'Wii', 'Games']],
#               'description': "We're putting a whole new twist on your favorite puzzle games! Experience the classic Crossword, Sudoku, Word Search, and Fitword puzzles you love with all-new, interactive video game play. With over 2,000 puzzles and three difficulty levels. Puzzler will wrack your brain as you try to solve them all! Play at home against your friends and family on the Nintendo Wii.",
#               'imUrl': 'http://ecx.images-amazon.com/images/I/51TKEPRRxPL._SY300_.jpg',
#               'price': 17.54,
#               'related': {'also_bought': ['B000S1L000',
#                 'B003S2JI6O',
#                 'B001AR0D3G',
#                 'B001L8DKLG',
#                 'B0017UDZA4',
#                 'B001CLG6RM',
#                 'B001C3N0RE',
#                 'B000ME3M5O',
#                 'B00182QCXS',
#                 'B000NKRJAG',
#                 'B00166PY5I',
#                 'B000SFK0SO',
#                 'B0045ILJ2Q',
#                 'B003V63V1A',
#                 'B003S2JI82',
#                 'B002EWD03Q',
#                 'B004W4STO4',
#                 'B0013KK84O',
#                 'B0036KRP6S',
#                 'B003VJMDIO',
#                 'B0039QWK0A',
#                 'B000OAO188',
#                 'B005GWU020',
#                 'B001EZ8IBS',
#                 'B003VJPS5E',
#                 'B003M986Z2',
#                 'B00559XGDO',
#                 'B002DC8GT0',
#                 'B005GWU00W',
#                 'B002FUI4N8',
#                 'B0014C6WBY',
#                 'B001EN3YUU'],
#                'bought_together': ['B000S1L000', 'B003S2JI6O'],
#                'buy_after_viewing': ['B000S1L000',
#                 'B001AR0D3G',
#                 'B004W4STO4',
#                 'B001L8DKLG']},
#               'salesRank': {'Video Games': 22943}},
#              'B0000D12XI': {'asin': 'B0000D12XI',
#               'categories': [['Video Games', 'PC', 'Games']],
#               'description': "In 2001,Max Paynearrived to set the benchmark for action gaming, earning countless awards and revolutionizing the genre with cinematic combat sequences fuelled by the groundbreaking use of slow motion and compulsive narrative-driven gameplay. Now, working together with Rockstar Games' New York-based production team, Remedy has combinedMax Payne's hallmark gameplay with all new innovations and unmatched production values.Max Payne 2: The Fall of Max Payneis set to raise the bar for action games all over again when it's released fall 2003.",
#               'imUrl': 'http://ecx.images-amazon.com/images/I/513YXDAF60L._SY300_.jpg',
#               'price': 14.99,
#               'related': {'also_bought': ['B00002SUOV',
#                 'B00178631E',
#                 'B0001PKC0M',
#                 'B002I0KOSI',
#                 'B004D8QAAO',
#                 'B001O4YSTU',
#                 'B005C2D2H4',
#                 'B0050SZ0SY',
#                 'B001Q96ZNU',
#                 'B007TRXBJY',
#                 'B002BS47YE',
#                 'B003ZULWQI',
#                 'B0042WXQ62',
#                 'B003GSZAOY',
#                 'B00022Q0RI',
#                 'B002SU4QG4',
#                 'B001BNFQKO',
#                 'B005G4CXPK',
#                 'B002LVUKIS',
#                 'B00006599Y',
#                 '0700026398',
#                 'B0050SWTS8',
#                 'B002I0HKRQ',
#                 'B003Q55Y5C',
#                 'B000B63RSA',
#                 'B0026EV5FC',
#                 'B00001KUII',
#                 'B001BC719O',
#                 'B000HMQE8S',
#                 'B001AZTU28'],
#                'buy_after_viewing': ['B00178631E',
#                 'B0000A92KX',
#                 'B00002SUOV',
#                 'B001AH8YSW']},
#               'salesRank': {'Video Games': 8531}},
#              'B0000D12XH': {'asin': 'B0000D12XH',
#               'categories': [['Video Games', 'Kids & Family'],
#                ['Video Games', 'PC', 'Games']],
#               'description': "The originalRailroad Tycoon, released in 1990, quickly became a tremendous critical and commercial success, and at the same time created the Tycoon genre of game play.The sequel,Railroad Tycoon 2, released in 1998, marked the rebirth of Tycoon games and was the first Tycoon game of the modern era, with great graphics, dozens of scenarios and Internet multi-player.TheRailroad Tycoonseries has received critical acclaim and won numerous awards, including the coveted 'Game Of The Year' from numerous publications. This successful franchise has sold in excess of two million copies and established a massive and passionate worldwide fan base.Now, the King and creator of the Tycoon genre is returning to reclaim its throne!The originalRailroad Tycoonwas created by world-renowned developer, Sid Meier. It was the first Tycoon game ever made, and successfully merged a well-crafted business model with a player friendly graphical presentation. Railroad Tycoon was a critical success, winning 'Game of the Year' from the major magazines of the day, and became a worldwide bestseller.In 1997, Phil Steinmeyer, CEO of PopTop and a huge fan of the originalRailroad Tycoongame, began work on a new railroad game, designed to be the spiritual successor toRailroad Tycoon. A year and a half laterRailroad Tycoon 2(published by Gathering), was released, and like it predecessor became a massive critical and commercial success, garnering many 'Strategy Game of the Year' and 'Game of the Year' type awards. With sales of over 1.5 million copies it was clear that Phil Steinmyer had accomplished his goal, in fact the game is still selling today five years later.Six months afterRailroad Tycoon 2launched, the gameRollercoaster Tycoonwas released and proved to be a huge success, holding the #1 slot in the PC sales charts for many weeks. The tycoon craze was on - dozens of games have launched over the years since, attempting to duplicate the formula that made theRailroad Tycoonseries resonate so soundly within the gaming communityNow, in 2003, PopTop and Gathering stand ready to releaseRailroad Tycoon 3, a big budget, gorgeous 3D transformation of the classic and the game that will usher in the third era of Tycoon games.",
#               'imUrl': 'http://ecx.images-amazon.com/images/I/51GVPQ5C5PL._SY300_.jpg',
#               'price': 19.99,
#               'related': {'also_bought': ['B000FU1F0O',
#                 'B00029PMOS',
#                 'B0001DLLZ4',
#                 'B00001SHON',
#                 'B000AOIES6',
#                 'B0057UWVDM',
#                 'B0000C0YW2',
#                 'B00006F7S8',
#                 'B00005NBR0',
#                 'B004JQK29K',
#                 'B00029QOQS',
#                 'B0001D7NYM',
#                 'B00005B4AS',
#                 'B00029QR7O',
#                 'B000HKGD4A',
#                 'B000EDPQMU',
#                 'B00005K89G',
#                 'B00005QX4B',
#                 'B00001SHOF',
#                 'B001BZ2F56',
#                 'B000IWMVSY',
#                 'B001DOMCQC',
#                 'B000A14PP0',
#                 'B000094FR7',
#                 'B00006471Z',
#                 'B002OH8U0Y',
#                 'B000BCGFBK',
#                 'B0026EGO3A',
#                 'B0009J8WZC',
#                 'B00AR7GMHG',
#                 'B0000695GX',
#                 'B0031ESIZQ',
#                 'B000R1CS5W',
#                 'B005M0KSIM',
#                 'B00005AG1J',
#                 'B000YIYB3K',
#                 'B00000K4MC',
#                 'B00GPH7Y8S',
#                 'B009S4JZKK',
#                 'B0012DPHKW',
#                 'B00005LBVS',
#                 'B006NU6RKS',
#                 'B0000634TW',
#                 '0744002990',
#                 'B00000G16I',
#                 '907843905X',
#                 'B0001D7NYC',
#                 'B00006LISN',
#                 'B005D5XTT6',
#                 'B00695VJ1Y',
#                 'B000C05XR8',
#                 'B00002NDEU',
#                 'B00004T1M7',
#                 'B0038TT8QM',
#                 'B001S1TRWM',
#                 '0307895408',
#                 'B00002S5ZB'],
#                'bought_together': ['B000FU1F0O'],
#                'buy_after_viewing': ['B000FU1F0O',
#                 'B001BZ2F56',
#                 'B0000C0YW2',
#                 'B000HD6TLE']},
#               'salesRank': {'Video Games': 5498}},
#              'B00189MNPC': {'asin': 'B00189MNPC',
#               'categories': [['Video Games',
#                 'Kids & Family',
#                 'Nintendo DS',
#                 'Games'],
#                ['Video Games', 'Nintendo DS', 'Games']],
#               'description': 'The blockbuster anime series on Cartoon Network returns with a sequel to the hit DS RPG Naruto: Path of the Ninja, featuring an original storyline, new characters, evolved graphics and more. Embark on a dramatic new mission with Naruto and his squad as they discover a mysterious valley and an ancient sealed evil about to put all their lives in danger.',
#               'imUrl': 'http://ecx.images-amazon.com/images/I/51YoZ95JJpL._SX300_.jpg',
#               'price': 58.33,
#               'related': {'also_bought': ['B000P297FM',
#                 'B003Z9L3EA',
#                 'B0026EV5LQ',
#                 'B000L22PDW',
#                 'B0011E08Y2',
#                 'B003Z9L3F4',
#                 'B003DC884C',
#                 'B00ADGT8UE',
#                 'B0026EV5M0',
#                 'B003VADS78',
#                 'B0030E5PXK',
#                 'B002S4DOA4',
#                 'B000G75AMU',
#                 'B003UN2IMM',
#                 'B00A1AQJAO',
#                 'B002HW5G2Q',
#                 'B00AYABWYE',
#                 'B003F3NEAC',
#                 'B000BNOINQ',
#                 'B001DO5BWY',
#                 'B00DUARBKY',
#                 'B001CZJOZY',
#                 'B003Z9L3FY',
#                 'B0036BDQ88',
#                 'B001A01FD0',
#                 'B003UI518U',
#                 'B0026EV5LG',
#                 '1421564556',
#                 'B003BE6OZ2',
#                 'B000SSQPU8',
#                 'B0038MVFYC',
#                 'B000NVKZ06',
#                 'B0046H0I14',
#                 'B001TOMR6Q',
#                 'B000R36AG8',
#                 'B000QXDG7K',
#                 'B0016AK37S',
#                 'B001PU8MTU',
#                 'B001BWRBA8',
#                 'B000IU5C5K',
#                 'B001H8Y7DA',
#                 'B002I08WVY',
#                 'B000F2DE8S',
#                 'B001NJRR7G',
#                 'B003S55EX2',
#                 '1421541254',
#                 'B002HJUX7C',
#                 'B005C2QSDY',
#                 'B007RUY1NS',
#                 'B0010YOQIM',
#                 'B0051TLC9I',
#                 'B0050SWXC0',
#                 'B001TD6SK8',
#                 'B000MRNUBC',
#                 'B002I0JNFI',
#                 '1421558858',
#                 'B002I08UPC',
#                 'B00030GS80',
#                 'B001C4J62Q',
#                 'B002I0K2J4',
#                 'B0050SVNP8',
#                 'B002MIK0TE',
#                 'B004K1EA5Q',
#                 'B000S8JXAM',
#                 'B0013B30SE',
#                 'B002I0EH6I',
#                 'B0053B5RGI',
#                 'B001E27DLM',
#                 'B0050SVNSU',
#                 'B000G75AXE',
#                 'B002I0IVC4',
#                 'B00171NYHM',
#                 'B005LUUWL6',
#                 'B003ZCDV7Y',
#                 'B0028WZ11G',
#                 'B00B67ZS3U',
#                 'B0088MVOTS',
#                 'B00136MBHA'],
#                'bought_together': ['B000P297FM', 'B003Z9L3EA'],
#                'buy_after_viewing': ['B003Z9L3EA',
#                 'B0026EV5M0',
#                 'B00ADGT8UE',
#                 'B0026EV5LQ']},
#               'salesRank': {'Video Games': 18020}},
#              'B00004T0QO': {'asin': 'B00004T0QO',
#               'categories': [['Video Games', 'PC', 'Games']],
#               'description': "TalonSoft's entire award-winning Campaign Series of war games in one box,Europe in Flamesallows you to play the Axis or the Allies on either the Eastern or Western front during World War II. Combining theEast FrontandWest Frontseries of games, along with all the expansion packs,Europe in Flamesdelivers over 280 scenarios--making it an excellent value for the novice and veteran war gamer alike.",
#               'imUrl': 'http://ecx.images-amazon.com/images/I/51DVZJ1ATQL._SY300_.jpg',
#               'price': 28.87,
#               'related': {'also_viewed': ['B00004ZB7N',
#                 'B000SM4ZHY',
#                 'B00003IEKQ'],
#                'buy_after_viewing': ['B00004ZB7N']},
#               'salesRank': {'Video Games': 53878}},
#              'B000AAUP00': {'asin': 'B000AAUP00',
#               'categories': [['Software', "Children's", 'Early Learning'],
#                ['Software', 'Lifestyle & Hobbies'],
#                ['Video Games', 'PC']],
#               'description': "Take the quick path to writing success!Product InformationQuickstudy English Composition will show students how to write with confidenceand skill whether they're having trouble starting a paper or just need anextra bit of polishing.&nbsp; From science to the humanities creative writingto journalism Quickstudy English Composition gives users the tools they need tomaster writing skills for all occasions.&nbsp; The curriculum-based lessons aredesigned by educators to help students understand and apply important writingconcepts in the classroom and beyond. Plus exercises and quizzes let studentseasily review new ideas.Subjects Covered Outlines Thesis Statements Proofreading Research Vocabulary Journalism Timed Writing College Essays Creative Writing Resumes Cover LettersProduct Features Be a quickstudy! Improve grades and test scores Write better research papers timed essays cover letters and more! Great for new learners or students studying for college entrance exams Covers dozens of areas in an engaging learning environment Features interactive review quizzes and fun writing activities Starts with basics and builds to plex topics Build writing skills fast Boost grades and essay scores Take the stress out of expressing yourselfWindows System Requirements Windows 98SE Me 2000 XP Vista Windows 7 (32-bit and 64-bit) 266 MHz processor or faster 32 MB RAM 170 MB free hard disk space SVGA monitor 256 colors Sound Blaster Pro-patible sound card &amp; speakers 4X CD-ROM drive Printer remended for printing lessonsMacintosh System Requirements Mac OS 8.5&ndash;9.2 OS X Classic mode 266 MHz processor or faster 32 MB RAM 100 MB free hard disk space SVGA monitor 256 colors 4X CD-ROM drive Printer remended for printing lessons",
#               'imUrl': 'http://ecx.images-amazon.com/images/I/41QUl8HbZfL._SY300_.jpg',
#               'price': 19.95,
#               'related': {'also_bought': ['B000RLKI04',
#                 'B000RLKHUK',
#                 'B000OC1ALW',
#                 'B00118Z42Y'],
#                'bought_together': ['B000RLKHUK'],
#                'buy_after_viewing': ['0977476065',
#                 '1580628559',
#                 'B000OC1ALW',
#                 '1423218655']},
#               'salesRank': {'Software': 12025}},
#              'B006P9GRLQ': {'asin': 'B006P9GRLQ',
#               'categories': [['Video Games',
#                 'PlayStation 3',
#                 'Accessories',
#                 'Accessory Kits']],
#               'description': 'Description:If you are experiencing the following problems with your console:Disc read errorsSlow loading timesFailure to read discScreen freezes when playing a game or watching a blu-ray movieThen, this should fix your problem.Fitment:You can look it up in the back of your PS3 console for the correct model#.PS3 console with single lens and it will fit the following models:Model CECHA01 CECHB01 CECHC02 CECHE01 CECHG01Numbers: CECHAxx CECHBxx CECHCxx CECHExx CECHGxxHard Drive Size: 60 GB 20 GB 60 GB 80 GB 40 GBKES-400A Yes Yes Yes Yes YesKES-400AAA Yes Yes Yes Yes YesKEM-400A Yes Yes Yes Yes YesKEM-400AAA Yes Yes Yes Yes YesPlease note:There is a 10% chance that CECHG01 and CECHE01MG /CECHxxMG with the MG use the dual lens KES-410A.The surest thing is to open up the unit and make sure that you purchase the correct laser lens module.Package Includes:1 x KES-400A KES-400AAA KEM-400A KEM-400AAA Laser Lens',
#               'imUrl': 'http://ecx.images-amazon.com/images/I/51F-U6U-U8L._SY300_.jpg',
#               'price': 38.73,
#               'related': {'also_bought': ['B003IDKR4A',
#                 'B002MROR7G',
#                 'B003ZUAVSS',
# ...
#                 'B00FENJVOE'],
#                'bought_together': ['B0007CQH3U'],
#                'buy_after_viewing': ['B000ANCVLI',
#                 'B00009MKGV',
#                 'B00014WM6U',
#                 'B00004U1P5']},
#               'salesRank': {'Video Games': 41268}},
#              'B0009X979I': {'asin': 'B0009X979I',
#               'categories': [['Video Games',
#                 'Kids & Family',
#                 'Sony PSP',
#                 'Games'],
#                ['Video Games', 'Sony PSP', 'Games']],
#               'description': 'Rockman Dash: Hagane no Boukenshin Japanese Format (NTSC-J). Box,package,',
#               'imUrl': 'http://ecx.images-amazon.com/images/I/51V4D67XXQL._SY300_.jpg',
#               'price': 79.8,
#               'related': {'also_viewed': ['B001KU7GCY',
#                 'B000JJFTC6',
#                 'B00004XONL',
#                 'B000069TET',
#                 'B000006OVJ',
#                 'B00000K1VC',
#                 'B000B69EA0',
#                 'B007T2UNGS',
#                 'B000CBCVEK',
#                 'B00DWR7ABK',
#                 'B003O6E800',
#                 'B003O6EATE'],
#                'bought_together': ['B000JJFTC6'],
#                'buy_after_viewing': ['B001KU7GCY']},
#               'salesRank': {'Video Games': 63118}},
#              'B00004ZBQL': {'asin': 'B00004ZBQL',
#               'categories': [['Video Games', 'Kids & Family'],
#                ['Video Games', 'PC', 'Games']],
#               'description': "For centuries the dragons of Pern and their riders have protected their world from the alien Thread. Mightiest among the dragons are the gold dragons and their riders, the Weyrwomen, who are the leaders of the free people of Weyr. And now your Weyrwoman is dead, and her gold dragon is dying. Unless you can find a new Weyrwoman to take up her mantle, your Weyr, and perhaps all of Pern, is doomed.Based in the sci-fi/fantasy world of Pern, the setting of Anne McCaffrey'sThe Dragonriders of Pernnovel, you take the role of D'kor, a novice dragonrider known as a Weyrling. Your fate is tied into a complex adventure in which the Red Star is not the only threat to life on Pern. With more than 200 characters with which to interact, a complex and thrilling story, and some fiendish puzzles, D'kor must venture across the rich world of Pern in the hope of saving it from its greatest enemy.Dragon Riders: Chronicles of Pernis a 3-D role-playing game with an epic story that spans four chapters and contains dozens of subplots. At the heart of the game is a story that constantly progresses as you explore the world and interact with the vast array of characters that inhabit it. Set at the seventh pass of the Red Star, there is a whole new cast of characters exclusive to this title. Experience dozens of environments through the cinematic camera system as you guide your dragonrider through more than 120 detailed locations on three continents. Interact with numerous non-player characters while you build up your player by improving skills and your social status.",
#               'imUrl': 'http://ecx.images-amazon.com/images/I/51WBTVNNASL._SY300_.jpg',
#               'price': 6.29,
#               'related': {'also_viewed': ['034550092X',
#                 '0345491157',
#                 '0345354249',
#                 '0345335465',
#                 'B0002BIDEM',
#                 '0345314344',
#                 '0345340248',
#                 '006105531X',
#                 '0345465652'],
#                'buy_after_viewing': ['0689860072',
#                 '034550092X',
#                 '0345491157',
#                 '0345354249']},
#               'salesRank': {'Video Games': 55815}},
#              'B0084ZYHLQ': {'asin': 'B0084ZYHLQ',
#               'categories': [['Video Games',
#                 'Kids & Family',
#                 'PlayStation Vita',
#                 'Games'],
#                ['Video Games', 'PlayStation Vita', 'Games']],
#               'description': '',
#               'imUrl': 'http://ecx.images-amazon.com/images/I/513jRE5T97L._SY300_.jpg',
#               'price': 29.99,
#               'related': {'also_bought': ['B006NYWLTU',
#                 'B006VB2W08',
#                 'B0050SW4OC',
#                 'B0050SW7PI',
#                 'B0088MVOD4',
#                 'B0050SW2NA',
#                 'B008OQTR1U',
#                 'B0050SWR6M',
#                 'B006WJ6YH6',
#                 'B0050SW33E',
#                 'B006VB2W1M',
#                 'B00D7QXAY2',
#                 'B00B73PFL8',
#                 'B006603W7Q',
#                 'B008277M0E',
#                 'B0050SW8AC',
#                 'B0088MVOU2',
#                 'B00DWXV1E6',
#                 'B0050SX0UY',
#                 'B0050SW1JK',
#                 'B006JI3Q7G',
#                 'B006P5RWCS',
#                 'B006JKARPS',
#                 'B006ZTHF62',
#                 'B00ICWO2CA',
#                 'B006JKASAC',
#                 'B0073ESYZO',
#                 'B006VB2V54',
#                 'B006JKASCK',
#                 'B006PP41Q8',
#                 'B006PP404Q',
#                 'B006JKARP8',
#                 'B006FRNAAE',
#                 'B009791CW0',
#                 'B00F27JGVA',
#                 'B00GY4OALG',
#                 'B003O6EATE',
#                 'B006FRNBB2',
#                 'B006WQR39M',
#                 'B006PP4136',
#                 'B00ECOAX20',
#                 'B0073ESZ58',
#                 'B005X6QNT8',
#                 'B006JKARZS',
#                 'B007AJZ5PY',
#                 'B0072LGIYM',
#                 'B00HYPWE2G',
#                 'B006VE40JQ',
#                 'B006JKAS6G',
#                 'B00GHIPFDG',
#                 'B00D8SYI86',
#                 'B00B7XCDCM',
#                 'B00IA2O0W4',
#                 'B00FZ24MZM',
#                 'B00KWIYPZG',
#                 'B00BI9MDSO',
#                 'B00FQCT1T8'],
#                'bought_together': ['B006VB2W08', 'B0050SW2NA'],
#                'buy_after_viewing': ['B0050SW2NA',
#                 'B006VB2W08',
#                 'B0050SW4OC',
#                 'B0050SW7PI']},
#               'salesRank': {'Video Games': 3333}},
#              'B00002SFLC': {'asin': 'B00002SFLC',
#               'categories': [['Video Games', 'Kids & Family'],
#                ['Video Games', 'PC', 'Games']],
#               'description': 'East Front 2is a stand-alone game that combines all the scenarios, campaigns, units and nationalities found inEast FrontandCampaign, while adding the new gaming features and improvements ofWest Front. It is tactical combat on the Eastern Front at its most complete and very finest. Besides compiling the features of the previous games,East Front 2also gives over 45 all-new scenarios, two new Dynamic Campaign Games, and two Linked Campaign Games, battles that can be found only in this release.',
#               'imUrl': 'http://ecx.images-amazon.com/images/I/51RTA4EY8FL._SY300_.jpg',
#               'price': 9.99,
#               'related': {'also_viewed': ['B00GPH7Y8S',
#                 'B00003IEKQ',
#                 'B000SM4ZHY',
#                 'B00002SSU3',
#                 'B00273Y7V6',
#                 'B003VM7WYQ',
#                 'B002CQAPWS',
#                 'B00GPH7W26',
#                 'B000CDP1IG',
#                 'B00004Z0FJ',
#                 'B00009KIM4',
#                 'B001ED5MFA',
#                 'B0002TA3QK'],
#                'buy_after_viewing': ['B00GPH7Y8S',
#                 'B000CQEI14',
#                 'B00004ZB7N']},
#               'salesRank': {'Video Games': 51707}},
#              'B00GSHOCEY': {'asin': 'B00GSHOCEY',
#               'categories': [['Video Games', 'Digital Games', 'Casual Games'],
#                ['Video Games', 'Digital Games', 'PC Game Downloads'],
#                ['Video Games', 'PC', 'Games']],
#               'description': '',
#               'imUrl': 'http://ecx.images-amazon.com/images/I/51oAjCxIwrL._SX300_.jpg',
#               'price': 1.99,
#               'related': {'also_bought': ['B00I47YYXK',
#                 'B00GRVACC2',
#                 'B00HA3BPXQ',
#                 'B00HNGGYPE',
#                 'B00HLMVSWE',
#                 'B00HNFR7EC',
#                 'B00GRN67ZG',
#                 'B00I9AZ7L0',
#                 'B00GRNRB2O',
#                 'B00HNEK5EM',
#                 'B00IK5URPU',
#                 'B00KINYVC2',
#                 'B00DCDTHII',
#                 'B00HDCUTUY',
#                 'B00IPK4E5O',
#                 'B00I0AIHZW',
#                 'B00IOPCQ28',
#                 'B00JF6E06A',
#                 'B00I0AIGX0',
#                 'B00I0BZG2S',
#                 'B00KG3W8X8',
#                 'B00C7B0GYK',
#                 'B00HF1306S',
#                 'B003FSSINA',
#                 'B00GQVGV9Q',
#                 'B00GRRYEAW',
#                 'B00HNXS11M',
#                 'B00ATST7H0',
#                 'B00KQYCHJM',
#                 'B00GRLC28E',
#                 'B009W68BK4',
#                 'B003FSSIOE',
#                 'B00CMDKNHI',
#                 'B00IHWG6R4',
#                 'B00HNFCQ4S',
#                 'B00JRMPL8I',
#                 'B00HK3RDPK',
#                 'B00GRSOMRQ',
#                 'B00GQYIAME',
#                 'B00FWR3M3I',
#                 'B00L45HS50',
#                 'B00FVVVSUY',
#                 'B00GQYOC4O',
#                 'B00GL52MDG',
#                 'B00IYWYSM2',
#                 'B00I0AIIVK',
#                 'B00JAQFVJK',
#                 'B00CD60EGO',
#                 'B00GRV5MI6',
#                 'B00CB0ZC1Y',
#                 'B00J37DE0O',
#                 'B00ATST7HK',
#                 'B005063OX4',
#                 'B007A5WCCC',
#                 'B00KFJ7XK6',
#                 'B00L8RLSNC',
#                 'B00LN4IU68',
#                 'B00B03H6GM',
#                 'B00GRN0YQ4',
#                 'B00JY8U9JG',
#                 'B00LEDB2YU',
#                 'B00GQVYBWK',
#                 'B00I2UDP8O',
#                 'B00C7B0GAE',
#                 'B006TJYRBE',
#                 'B00KY0P9O8',
#                 'B00BQHQQW2',
#                 'B00KGCPT4O',
#                 'B00HDC5IW8',
#                 'B0080XYCO4',
#                 'B00JAQFXCU',
#                 'B00GQWRJDM',
#                 'B0045U9Q9M',
#                 'B004OYTV3A',
#                 'B00KY1SASO',
#                 'B00JKWWWOG',
#                 'B002JPIZZ6',
#                 'B00BXONG7Q',
#                 'B005KCIY0Q',
#                 'B00HA5XAB4',
#                 'B00GRU7SN4',
#                 'B00G4D3QY4',
#                 'B00HF0D9YC',
#                 'B0090NQQTW',
#                 'B001KC011K',
#                 'B00CIY9MH8',
#                 'B00GGZGW8W',
#                 'B00HDPIFYI',
#                 'B00B2B4PN4',
#                 'B00B1GG36W',
#                 'B00J37DL8O',
#                 'B00LA89DW2',
#                 'B003UD7RV4',
#                 'B00JXHJLE2',
#                 'B008BAGU3C',
#                 'B00HNFLDL0',
#                 'B00GRULBI2',
#                 'B00GRS8B4G'],
#                'buy_after_viewing': ['B003FSSIOE',
#                 'B00GRVACC2',
#                 'B00HA3BPXQ',
#                 'B00IPK4E5O']},
#               'salesRank': {'Video Games': 20343}},
#              'B00008NNY0': {'asin': 'B00008NNY0',
#               'categories': [['Electronics',
#                 'Computers & Accessories',
#                 'Computer Components'],
#                ['Software', 'Design & Illustration'],
#                ['Software', 'Music', 'CD Burning & Labeling'],
#                ['Software', 'Video'],
#                ['Video Games', 'PC']],
#               'description': 'Designed for novices and power users alike, Pinnacle Systems InstantCD/DVD provides end-to-end production of any burning project--from capture to labels. Rip, clean and burn MP3 files onto play-anywhere audio CDs. Sample audio and arrange 16-track stereo music. Capture, edit and share digital photos and home movies on CDs or DVDs that can be viewed on practically any home DVD player. InstantCD/DVD also rapidly burns flawless copies of DVDs and CDs, backs up data to any removable storage medium including recordable CDs and DVDs, and lets you use a CD/DVD burner drive as you would a floppy or hard drive.',
#               'imUrl': 'http://ecx.images-amazon.com/images/I/51FXCZ4Z0ML._SY300_.jpg',
#               'price': 27.99,
#               'related': {'also_viewed': ['B004QMT9D2',
#                 'B00062VOW0',
#                 'B00FB5R6L0',
#                 'B00FB5R4L2',
#                 'B00F9ZQQ8Q',
#                 'B00FB5R4SA',
#                 'B006GOFW3E',
#                 'B00006B8GK',
#                 'B0040FT30O',
#                 'B0007XPV22',
#                 'B009716GWE',
#                 'B000CBZZQ6',
#                 'B004QK8FBG',
#                 'B005CELIKU',
#                 'B003Z3LGPW',
#                 'B009DZGMGE',
#                 'B00B5P23SG'],
#                'buy_after_viewing': ['B004QMT9D2', 'B00062VOW0']},
#               'salesRank': {'Software': 12845}},
#              'B001VNF1QI': {'asin': 'B001VNF1QI',
#               'categories': [['Video Games',
#                 'Xbox 360',
#                 'Accessories',
#                 'Cables & Adapters',
#                 'Cables']],
#               'description': '3 prong AC power supply for PS3.  Compatible with PS3, Xbox 360 and most PCs.  6 feet in length.',
#               'imUrl': 'http://ecx.images-amazon.com/images/I/41T9V9y30aL._SY300_.jpg',
#               'price': 0.33,
#               'related': {'also_bought': ['B002TK1Q3Y',
#                 'B0011ACZM4',
#                 'B0011E82F4',
#                 'B000PT18OS',
#                 'B000087R8F',
#                 'B001QWVW2G',
#                 'B004W7GJ6Q',
#                 'B004QS30W2',
#                 'B000B6MLPU',
#                 'B00309S9YW',
#                 'B003ZSP0WW',
#                 'B005HN5LKY',
#                 'B007LQG9A6',
#                 'B000SJ5ZX0',
#                 'B0035XYQPE',
#                 'B004HX5OFW',
#                 'B003WM1P5W',
#                 'B000O62OS6',
#                 'B0037LXWM2',
#                 'B002ZKTHD4',
#                 'B0062E3YU6',
#                 'B0050SYILE',
#                 'B001MNTVNQ',
#                 'B003O6JKLC',
#                 'B0073QM45I',
#                 'B002DC8GKE',
#                 'B003D3OOYY',
#                 'B007MJSZDQ',
#                 'B002I098JE',
#                 'B004HX1QFY',
#                 'B007XVTR3K',
#                 'B00BU3ZLJQ',
#                 'B001E65P72',
#                 'B008U2XECG',
#                 'B004HYK956',
#                 'B00269QLI8',
#                 'B000B6MLPK',
#                 'B00C710AZ0',
#                 'B00CD90R4K',
#                 'B0032A8SLS',
#                 'B00BOEZNGW',
#                 'B004YV9U7U',
#                 'B003A71XKQ',
#                 'B00AY1CT4U'],
#                'bought_together': ['B002TK1Q3Y'],
#                'buy_after_viewing': ['B004QS30W2',
#                 'B005HN5LKY',
#                 'B000PT18OS',
#                 'B0052N0P8C']},
#               'salesRank': {'Video Games': 3273}},
#              'B0002DRISM': {'asin': 'B0002DRISM',
#               'categories': [['Video Games', 'Kids & Family'],
#                ['Video Games', 'Mac', 'Games']],
#               'description': "Join Belle and Beast, Chip and Mrs. Potts and Lumiere and Cogsworth on an exciting journey through secret passages and hidden surprises. Decorate the ballroom, dress up Belle and Beast, arrange music, create the dance steps and design your own ball. Build stained-glass creations just like in Beast's castle with Lumiere. Unravel the mysteries and discover the hidden passages in the library with Cogsworth to find the hidden key to the West Wing. Help Mrs. Potts prepare for a feast, arcade style, in the chaos of the kitchen. Beauty and the Beast captures all of the magic and arrives inside a special Princess purse.",
#               'imUrl': 'http://ecx.images-amazon.com/images/I/41aMDQsAIiL._SX300_.jpg',
#               'price': 10.99,
#               'related': {'also_viewed': ['B00006F2EL'],
#                'buy_after_viewing': ['B003XQRYYS',
#                 'B000031VUX',
#                 'B00004U5R4']},
#               'salesRank': {'Software': 6007}},
#              ...})
